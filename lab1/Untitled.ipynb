# %%
# %run Part1_Tokenisation.py

# %%
torch.manual_seed(42)
print("=== Category classifier ===")
vec_cat, model_cat = train(train_file="reviews-train.txt", label=0)

torch.manual_seed(42)
print("\n=== Sentiment classifier ===")
vec_sent, model_sent = train(train_file="reviews-train.txt", label=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 torch.manual_seed(42)
#       2 print("=== Category classifier ===")
#       3 vec_cat, model_cat = train(train_file="reviews-train.txt", label=0)
#
# NameError: name 'torch' is not defined

# %%
python Part1_Tokenisation.py
# Out:
#   Cell In[2], line 1
#     python Part1_Tokenisation.py
#            ^
# SyntaxError: invalid syntax

# %%
Part1_Tokenisation.py
